# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
cities
# Out:
# ['ugoofaaru',
#  'ilulissat',
#  'butaritari',
#  'hermanus',
#  'torbay',
#  'kodiak',
#  'lasa',
#  'vaini',
#  'autazes',
#  'avarua',
#  'kahului',
#  'newport',
#  'sitka',
#  'taolanaro',
#  'mataura',
#  'biak',
#  'non thai',
#  'new norfolk',
#  'rawson',
#  'bambous virieux',
#  'archidona',
#  'punta arenas',
#  'haines junction',
#  'mount gambier',
#  'kapaa',
#  'port elizabeth',
#  'ust-ilimsk',
#  'manggar',
#  'jamestown',
#  'lalmohan',
#  'illoqqortoormiut',
#  'rikitea',
#  'ulladulla',
#  'concepcion del uruguay',
#  'pokoynoye',
#  'beyneu',
#  'chernyshevskiy',
#  'ciudad bolivar',
#  'kuryk',
#  'bluff',
#  'yulara',
#  'cape town',
#  'lebu',
#  'tignere',
#  'attawapiskat',
#  'bontang',
#  'yenisehir',
#  'monte alegre',
#  'port alfred',
#  'santa rosalia',
#  'tete',
#  'busselton',
#  'albany',
#  'ostrovnoy',
#  'namibe',
#  'airai',
#  'saint george',
#  'vanimo',
#  'lagoa',
#  'rorvik',
#  'adrar',
#  'bandarbeyla',
#  'priargunsk',
#  'pemangkat',
#  'prince rupert',
#  'ushuaia',
#  'lhokseumawe',
#  'ca mau',
#  'colinas',
#  'tiksi',
#  'bredasdorp',
#  'naze',
#  'tombouctou',
#  'brownwood',
#  'cap-aux-meules',
#  'xifeng',
#  'itarema',
#  'itamaraca',
#  'armacao dos buzios',
#  'shihezi',
#  'mercedes',
#  'basco',
#  'ahipara',
#  'barawe',
#  'kavaratti',
#  'vaitupu',
#  'vestmannaeyjar',
#  'karaul',
#  'fortuna',
#  'pocosol',
#  'douentza',
#  'castro',
#  'chokurdakh',
#  'flin flon',
#  'solnechnyy',
#  'carutapera',
#  'along',
#  'najran',
#  'sentyabrskiy',
#  'moron',
#  'qaanaaq',
#  'skibbereen',
#  'imbituba',
#  'hobart',
#  'nikolskoye',
#  'stromness',
#  'leningradskiy',
#  'hasaki',
#  'visnes',
#  'galesong',
#  'hamilton',
#  'den helder',
#  'chuy',
#  'lakes entrance',
#  'saldanha',
#  'barrow',
#  'san cristobal',
#  'severo-kurilsk',
#  'grand baie',
#  'okha',
#  'the pas',
#  'esperance',
#  'puerto ayora',
#  'fernie',
#  'barentsburg',
#  'cayenne',
#  'mwense',
#  'havre-saint-pierre',
#  'zhigansk',
#  'poum',
#  'berlevag',
#  'zhovkva',
#  'atuona',
#  'lima',
#  'aktash',
#  'talara',
#  'upernavik',
#  'lompoc',
#  'rundu',
#  'mackay',
#  'mar del plata',
#  'cabo san lucas',
#  'sola',
#  'wagar',
#  'kamenskoye',
#  'la ronge',
#  'lorengau',
#  'aklavik',
#  'hurup',
#  'jaisalmer',
#  'half moon bay',
#  'chemal',
#  'rungata',
#  'thohoyandou',
#  'pagman',
#  'tura',
#  'nanortalik',
#  'urubicha',
#  'kruisfontein',
#  'yellowknife',
#  'bandar-e lengeh',
#  'muborak',
#  'puri',
#  'bethel',
#  'constitucion',
#  'saskylakh',
#  'haikou',
#  'armeria',
#  'murzzuschlag',
#  'conde',
#  'santa lucia',
#  'cidreira',
#  'amderma',
#  'kalaiya',
#  'benguela',
#  'san juan',
#  'mahebourg',
#  'mingaora',
#  'hannibal',
#  'tasiilaq',
#  'jacmel',
#  'denia',
#  'malwan',
#  'tuktoyaktuk',
#  'vrangel',
#  'ghanzi',
#  'korla',
#  'egvekinot',
#  'saurimo',
#  'bengkulu',
#  'pochutla',
#  'miranda de ebro',
#  'moussoro',
#  'talaya',
#  'kidal',
#  'aleksandrov gay',
#  'placido de castro',
#  'san patricio',
#  'belmonte',
#  'saint-pierre',
#  'sari',
#  'saleaula',
#  'hithadhoo',
#  'dapaong',
#  'deputatskiy',
#  'belaya gora',
#  'chumikan',
#  'dingle',
#  'kroya',
#  'kaka',
#  'grand river south east',
#  'we',
#  'ribeira grande',
#  'liverpool',
#  'falealupo',
#  'halalo',
#  'sorland',
#  'victoria',
#  'muros',
#  'ketchikan',
#  'tumannyy',
#  'salinopolis',
#  'faanui',
#  'baghdad',
#  'banamba',
#  'bukachacha',
#  'garowe',
#  'belushya guba',
#  'yerofey pavlovich',
#  'kokopo',
#  'thompson',
#  'nago',
#  'galiwinku',
#  'marcona',
#  'nalut',
#  'pariquera-acu',
#  'panama city',
#  'narsaq',
#  'asau',
#  'zabid',
#  'uyuni',
#  'warqla',
#  'isla vista',
#  'kupang',
#  'ucluelet',
#  'hilo',
#  'valparaiso',
#  'sibanicu',
#  'faya',
#  'benjamin constant',
#  'accra',
#  'mehamn',
#  'karla',
#  'antofagasta',
#  'heihe',
#  'thongwa',
#  'port keats',
#  'marawi',
#  'bosaso',
#  'souillac',
#  'khatanga',
#  'florianopolis',
#  'bargal',
#  'tuatapere',
#  'alice springs',
#  'ust-tsilma',
#  'san quintin',
#  'grand forks',
#  'nuuk',
#  'umzimvubu',
#  'aykhal',
#  'high level',
#  'longyearbyen',
#  'mazagao',
#  'norman wells',
#  'valley',
#  'brae',
#  'east london',
#  'sellye',
#  'yamada',
#  'te anau',
#  'kansanshi',
#  'hunchun',
#  'kapit',
#  'finnsnes',
#  'liberal',
#  'nizhneyansk',
#  'linxia',
#  'arraial do cabo',
#  'eureka',
#  'darnah',
#  'burica',
#  'cam pha',
#  'muzhi',
#  'petropavlovsk-kamchatskiy',
#  'maragogi',
#  'domoni',
#  'kaeo',
#  'port hardy',
#  'college',
#  'tungkang',
#  'ngukurr',
#  'isoka',
#  'paragominas',
#  'chimbote',
#  'maturin',
#  'morehead',
#  'mitsamiouli',
#  'gat',
#  'pisco',
#  'hualmay',
#  'carnarvon',
#  'luderitz',
#  'ukiah',
#  'des plaines',
#  'satitoa',
#  'alofi',
#  'baependi',
#  'tungor',
#  'sao joao da barra',
#  'rona de jos',
#  'buala',
#  'mwene-ditu',
#  'gizo',
#  'russkiy',
#  'rasskazovo',
#  'nassau',
#  'saint-philippe',
#  'orotukan',
#  'grindavik',
#  'ulfborg',
#  'balkhash',
#  'yuanping',
#  'provideniya',
#  'san angelo',
#  'kudchi',
#  'bucerias',
#  'coquimbo',
#  'kozhva',
#  'muana',
#  'russell',
#  'sao filipe',
#  'karaton',
#  'chifeng',
#  'hambantota',
#  'homer',
#  'anito',
#  'tezu',
#  'port-cartier',
#  'hammerfest',
#  'ayan',
#  'aksarka',
#  'kolimvari',
#  'kaitangata',
#  'komsomolskiy',
#  'riyadh',
#  'koumac',
#  'shingu',
#  'bakel',
#  'sechura',
#  'pevek',
#  'long xuyen',
#  'port lincoln',
#  'coronado',
#  'redlands',
#  'tiarei',
#  'aragarcas',
#  'powell river',
#  'baker city',
#  'raudeberg',
#  'bambanglipuro',
#  'fairbanks',
#  'northam',
#  'grande-riviere',
#  'ust-maya',
#  'at-bashi',
#  'port augusta',
#  'goya',
#  'kijang',
#  'bonavista',
#  'sao jose da coroa grande',
#  'dikson',
#  'vardo',
#  'greenville',
#  'okato',
#  'araria',
#  'sayat',
#  'muisne',
#  'guerrero negro',
#  'ixtapa',
#  'banikoara',
#  'mecca',
#  'cherskiy',
#  'richards bay',
#  'corowa',
#  'rovaniemi',
#  'doctor pedro p. pena',
#  'bereda',
#  'iqaluit',
#  'pemba',
#  'lohardaga',
#  'marzuq',
#  'griffith',
#  'ivanivka',
#  'hovd',
#  'togur',
#  'nara',
#  'khash',
#  'geraldton',
#  'grenada',
#  'kautokeino',
#  'ust-nera',
#  'tabukiniberu',
#  'ust-kuyga',
#  'baloda bazar',
#  'chagda',
#  'takoradi',
#  'sioux lookout',
#  'ancud',
#  'katsuura',
#  'codrington',
#  'lao cai',
#  'verkhoyansk',
#  'urusha',
#  'santa cruz',
#  'saint-joseph',
#  'puerto colombia',
#  'karwar',
#  'santa quiteria',
#  'mao',
#  'huarmey',
#  'semnan',
#  'zavodouspenskoye',
#  'tautira',
#  'auki',
#  'villa union',
#  'ankang',
#  'urengoy',
#  'socorro',
#  'mys shmidta',
#  'maningrida',
#  'gniezno',
#  'campoverde',
#  'bobonong',
#  'bridgton',
#  'pangnirtung',
#  'kavieng',
#  'channelview',
#  'maumere',
#  'talnakh',
#  'husavik',
#  'manalurpet',
#  'quelimane',
#  'beringovskiy',
#  'chippewa falls',
#  'ponta do sol',
#  'laiyang',
#  'taylorville',
#  'parana',
#  'laguna',
#  'sladkovo',
#  'novikovo',
#  'petropavlovka',
#  'kloulklubed',
#  'khandyga',
#  'murdochville',
#  'milevsko',
#  'koungou',
#  'prescott',
#  'neepawa',
#  'tsihombe',
#  'sahuaripa',
#  'erzin',
#  'portland',
#  'amuntai',
#  'play cu',
#  'khor',
#  'obidos',
#  'sampit',
#  'isangel',
#  'macau',
#  'xining',
#  'khonuu',
#  'kambove',
#  'vila velha',
#  'caravelas',
#  'alihe',
#  'sembe',
#  'psebay',
#  'maloh',
#  'kholm',
#  'vengerovo',
#  'glowno',
#  'ambodifototra',
#  'tallahassee',
#  'gazli',
#  'viedma',
#  'narasannapeta',
#  'bozoum',
#  'wernberg',
#  'kearns',
#  'moba',
#  'wanaka',
#  'sinnar',
#  'bichena',
#  'bardiyah',
#  'okhotsk',
#  'ambon',
#  'leshukonskoye',
#  'stavern',
#  'cascavel',
#  'gorom-gorom',
#  'male',
#  'barlinek',
#  'kudahuvadhoo',
#  'flagstaff',
#  'svetlaya',
#  'providencia',
#  'srednekolymsk',
#  'dujuma',
#  'liwale',
#  'upata',
#  'adre',
#  'jieshi',
#  'marsabit',
#  'jilin',
#  'chermoz',
#  'jalu',
#  'kandiari',
#  'makaryev',
#  'creston',
#  'galashki',
#  'taikang',
#  'gourcy',
#  'lata',
#  'honiara',
#  'port macquarie',
#  'burgersdorp',
#  'lolua',
#  'taywarah',
#  'panjakent',
#  'saryagash',
#  'presidente dutra',
#  'koroni',
#  'pudozh',
#  'cockburn town',
#  'cockburn harbour',
#  'chirongui',
#  'sept-iles',
#  'dhidhdhoo',
#  'esmeraldas',
#  'morant bay',
#  'jiuquan',
#  'paita',
#  'shiraoi',
#  'hohhot',
#  'manzanillo',
#  'severnyy',
#  'flinders',
#  'kudirkos naumiestis',
#  'yunjinghong',
#  'agadez',
#  'leh',
#  'salalah',
#  'halifax',
#  'pacific grove',
#  'oranjemund',
#  'palabuhanratu',
#  'henties bay',
#  'bealanana',
#  'mogochin',
#  'port hawkesbury',
#  'tabiauea',
#  'westport',
#  'pandan',
#  'camacha',
#  'masindi',
#  'panaba',
#  'nueva concepcion',
#  'jumla',
#  'monrovia',
#  'odienne',
#  'shubarshi',
#  'hay river',
#  'kuusamo',
#  'waipawa',
#  'kimbe',
#  'sur',
#  'joshimath',
#  'labuan',
#  'mogadouro',
#  'rio grande',
#  'miri',
#  'sungaipenuh',
#  'valleyview',
#  'tazovskiy',
#  'seymchan',
#  'bangassou',
#  'arman',
#  'limenaria',
#  'merauke',
#  'vangaindrano',
#  'yerbogachen',
#  'celestun',
#  'pasni',
#  'kasongo-lunda',
#  'fredonia',
#  'haifa',
#  'vanavara',
#  'zhanakorgan',
#  'gornyy',
#  'kropotkin',
#  'matagami',
#  'ibotirama',
#  'balkanabat',
#  'georgetown',
#  'fort frances',
#  'kishtwar',
#  'saryshagan',
#  'nang rong',
#  'tromso',
#  'dom pedrito',
#  'umm ruwabah',
#  'borgosesia',
#  'necochea',
#  'milkovo',
#  'ende',
#  'iquitos',
#  'addis zemen',
#  'kuandian',
#  'jackson',
#  'saint-augustin',
#  'samusu',
#  'turukhansk',
#  'kontagora',
#  'nome',
#  'grand-lahou',
#  'velyka bahachka',
#  'howard springs',
#  'shelburne',
#  'banda aceh',
#  'moundou',
#  'traralgon',
#  'quesnel',
#  'raton',
#  'chengde',
#  'mormugao',
#  'maghama',
#  'marhaura',
#  'vetluzhskiy',
#  'tanete',
#  'ialibu',
#  'kutum',
#  'nata',
#  'yangjiang',
#  'anadyr',
#  'bayan',
#  'vostok',
#  'balassagyarmat',
#  'dunedin',
#  'manta',
#  'bogatyye saby',
#  'nemuro',
#  'san francisco',
#  'pontianak',
#  'matay',
#  'chupa',
#  'garden city',
#  'uniara',
#  'uruguaiana',
#  'vila franca do campo',
#  'kununurra',
#  'melton',
#  'shepsi',
#  'toktogul',
#  'sarangani',
#  'slave lake',
#  'cosala',
#  'lavrentiya',
#  'leon valley',
#  'palu',
#  'wuwei',
#  'athabasca',
#  'thunder bay',
#  'asosa',
#  'west melbourne',
#  'krasnovishersk',
#  'laela',
#  'misratah',
#  'shimoda',
#  'amapa',
#  'orcopampa',
#  'kiruna',
#  'atasu',
#  'santa isabel do rio negro',
#  'nelson bay',
#  'batticaloa',
#  'evensk',
#  'benghazi',
#  'sao luiz gonzaga',
#  'joppatowne',
#  'bac lieu',
#  'springbok',
#  'praia',
#  'corinto',
#  'waingapu',
#  'lovozero',
#  'kalianget',
#  'bonfim',
#  'talcahuano',
#  'comodoro rivadavia',
#  'fort saint john',
#  'tessalit',
#  'derzhavinsk',
#  'kindu',
#  'bud',
#  'clyde river',
#  'bridlington',
#  'ambulu',
#  'cabedelo',
#  'walla walla',
#  'acapulco',
#  'kandrian',
#  'arlit',
#  'tongling',
#  'goderich',
#  'walvis bay',
#  'kazalinsk',
#  'maxixe',
#  'zyryanka',
#  'sinnamary',
#  'shenjiamen',
#  'charters towers',
#  'fort nelson',
#  'groningen',
#  'coihaique',
#  'brantford',
#  'yurimaguas',
#  'wattegama',
#  'sao francisco de assis',
#  'ures',
#  'abu samrah',
#  'mikhaylovka',
#  'serdobsk',
#  'vostochnyy',
#  'ban nahin',
#  'porto de moz',
#  'hobyo',
#  'green river',
#  'gladstone',
#  'umm kaddadah',
#  'anloga',
#  'loandjili',
#  'kimberley',
#  'rocha',
#  'gold coast',
#  'andenes',
#  'lincoln',
#  'taloqan',
#  'hornepayne',
#  'winnemucca',
#  'beloha',
#  'north branch',
#  'mantua',
#  'sesheke',
#  'aniva',
#  'paraiso',
#  'atyrau']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2d399e1209786f755b80a87a3662f434

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'},
#   {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}],
#  'base': 'stations',
#  'main': {'temp': 41.68,
#   'feels_like': 37.92,
#   'temp_min': 37.53,
#   'temp_max': 45.05,
#   'pressure': 1022,
#   'humidity': 96},
#  'visibility': 402,
#  'wind': {'speed': 5.75, 'deg': 140},
#  'rain': {'1h': 0.6},
#  'clouds': {'all': 100},
#  'dt': 1643928785,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1643889346,
#   'sunset': 1643925619},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ugoofaaru
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | lasa
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | autazes
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | kahului
# Processing Record 12 of Set 1 | newport
# Processing Record 13 of Set 1 | sitka
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | biak
# Processing Record 17 of Set 1 | non thai
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | rawson
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | archidona
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | haines junction
# Processing Record 24 of Set 1 | mount gambier
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | ust-ilimsk
# Processing Record 28 of Set 1 | manggar
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | lalmohan
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | ulladulla
# Processing Record 34 of Set 1 | concepcion del uruguay
# Processing Record 35 of Set 1 | pokoynoye
# Processing Record 36 of Set 1 | beyneu
# Processing Record 37 of Set 1 | chernyshevskiy
# Processing Record 38 of Set 1 | ciudad bolivar
# Processing Record 39 of Set 1 | kuryk
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | yulara
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | tignere
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | bontang
# Processing Record 47 of Set 1 | yenisehir
# Processing Record 48 of Set 1 | monte alegre
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | santa rosalia
# Processing Record 1 of Set 2 | tete
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | namibe
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | vanimo
# Processing Record 9 of Set 2 | lagoa
# Processing Record 10 of Set 2 | rorvik
# Processing Record 11 of Set 2 | adrar
# Processing Record 12 of Set 2 | bandarbeyla
# Processing Record 13 of Set 2 | priargunsk
# Processing Record 14 of Set 2 | pemangkat
# Processing Record 15 of Set 2 | prince rupert
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | lhokseumawe
# Processing Record 18 of Set 2 | ca mau
# Processing Record 19 of Set 2 | colinas
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | naze
# Processing Record 23 of Set 2 | tombouctou
# Processing Record 24 of Set 2 | brownwood
# Processing Record 25 of Set 2 | cap-aux-meules
# Processing Record 26 of Set 2 | xifeng
# Processing Record 27 of Set 2 | itarema
# Processing Record 28 of Set 2 | itamaraca
# Processing Record 29 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 30 of Set 2 | shihezi
# Processing Record 31 of Set 2 | mercedes
# Processing Record 32 of Set 2 | basco
# Processing Record 33 of Set 2 | ahipara
# Processing Record 34 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 2 | kavaratti
# Processing Record 36 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 2 | vestmannaeyjar
# Processing Record 38 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 2 | fortuna
# Processing Record 40 of Set 2 | pocosol
# Processing Record 41 of Set 2 | douentza
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | flin flon
# Processing Record 45 of Set 2 | solnechnyy
# Processing Record 46 of Set 2 | carutapera
# Processing Record 47 of Set 2 | along
# Processing Record 48 of Set 2 | najran
# Processing Record 49 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | moron
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | skibbereen
# Processing Record 3 of Set 3 | imbituba
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | stromness
# Processing Record 7 of Set 3 | leningradskiy
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | visnes
# Processing Record 10 of Set 3 | galesong
# Processing Record 11 of Set 3 | hamilton
# Processing Record 12 of Set 3 | den helder
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | lakes entrance
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | san cristobal
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | grand baie
# Processing Record 20 of Set 3 | okha
# Processing Record 21 of Set 3 | the pas
# Processing Record 22 of Set 3 | esperance
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | fernie
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | mwense
# Processing Record 28 of Set 3 | havre-saint-pierre
# Processing Record 29 of Set 3 | zhigansk
# Processing Record 30 of Set 3 | poum
# Processing Record 31 of Set 3 | berlevag
# Processing Record 32 of Set 3 | zhovkva
# Processing Record 33 of Set 3 | atuona
# Processing Record 34 of Set 3 | lima
# Processing Record 35 of Set 3 | aktash
# Processing Record 36 of Set 3 | talara
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | lompoc
# Processing Record 39 of Set 3 | rundu
# Processing Record 40 of Set 3 | mackay
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | sola
# Processing Record 44 of Set 3 | wagar
# Processing Record 45 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 3 | la ronge
# Processing Record 47 of Set 3 | lorengau
# Processing Record 48 of Set 3 | aklavik
# Processing Record 49 of Set 3 | hurup
# Processing Record 50 of Set 3 | jaisalmer
# Processing Record 1 of Set 4 | half moon bay
# Processing Record 2 of Set 4 | chemal
# Processing Record 3 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 4 | thohoyandou
# Processing Record 5 of Set 4 | pagman
# City not found. Skipping...
# Processing Record 6 of Set 4 | tura
# Processing Record 7 of Set 4 | nanortalik
# Processing Record 8 of Set 4 | urubicha
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | bandar-e lengeh
# Processing Record 12 of Set 4 | muborak
# Processing Record 13 of Set 4 | puri
# Processing Record 14 of Set 4 | bethel
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | saskylakh
# Processing Record 17 of Set 4 | haikou
# Processing Record 18 of Set 4 | armeria
# Processing Record 19 of Set 4 | murzzuschlag
# Processing Record 20 of Set 4 | conde
# Processing Record 21 of Set 4 | santa lucia
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 4 | kalaiya
# Processing Record 25 of Set 4 | benguela
# Processing Record 26 of Set 4 | san juan
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | mingaora
# Processing Record 29 of Set 4 | hannibal
# Processing Record 30 of Set 4 | tasiilaq
# Processing Record 31 of Set 4 | jacmel
# Processing Record 32 of Set 4 | denia
# Processing Record 33 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 4 | tuktoyaktuk
# Processing Record 35 of Set 4 | vrangel
# Processing Record 36 of Set 4 | ghanzi
# Processing Record 37 of Set 4 | korla
# Processing Record 38 of Set 4 | egvekinot
# Processing Record 39 of Set 4 | saurimo
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | pochutla
# Processing Record 42 of Set 4 | miranda de ebro
# Processing Record 43 of Set 4 | moussoro
# Processing Record 44 of Set 4 | talaya
# Processing Record 45 of Set 4 | kidal
# Processing Record 46 of Set 4 | aleksandrov gay
# Processing Record 47 of Set 4 | placido de castro
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | belmonte
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | sari
# Processing Record 2 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 5 | hithadhoo
# Processing Record 4 of Set 5 | dapaong
# Processing Record 5 of Set 5 | deputatskiy
# Processing Record 6 of Set 5 | belaya gora
# Processing Record 7 of Set 5 | chumikan
# Processing Record 8 of Set 5 | dingle
# Processing Record 9 of Set 5 | kroya
# Processing Record 10 of Set 5 | kaka
# Processing Record 11 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 5 | we
# City not found. Skipping...
# Processing Record 13 of Set 5 | ribeira grande
# Processing Record 14 of Set 5 | liverpool
# Processing Record 15 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 16 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | victoria
# Processing Record 19 of Set 5 | muros
# Processing Record 20 of Set 5 | ketchikan
# Processing Record 21 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 5 | salinopolis
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | baghdad
# Processing Record 25 of Set 5 | banamba
# Processing Record 26 of Set 5 | bukachacha
# Processing Record 27 of Set 5 | garowe
# Processing Record 28 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | yerofey pavlovich
# Processing Record 30 of Set 5 | kokopo
# Processing Record 31 of Set 5 | thompson
# Processing Record 32 of Set 5 | nago
# Processing Record 33 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 34 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 5 | nalut
# Processing Record 36 of Set 5 | pariquera-acu
# City not found. Skipping...
# Processing Record 37 of Set 5 | panama city
# Processing Record 38 of Set 5 | narsaq
# Processing Record 39 of Set 5 | asau
# Processing Record 40 of Set 5 | zabid
# Processing Record 41 of Set 5 | uyuni
# Processing Record 42 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 5 | isla vista
# Processing Record 44 of Set 5 | kupang
# Processing Record 45 of Set 5 | ucluelet
# Processing Record 46 of Set 5 | hilo
# Processing Record 47 of Set 5 | valparaiso
# Processing Record 48 of Set 5 | sibanicu
# Processing Record 49 of Set 5 | faya
# Processing Record 50 of Set 5 | benjamin constant
# Processing Record 1 of Set 6 | accra
# Processing Record 2 of Set 6 | mehamn
# Processing Record 3 of Set 6 | karla
# Processing Record 4 of Set 6 | antofagasta
# Processing Record 5 of Set 6 | heihe
# Processing Record 6 of Set 6 | thongwa
# Processing Record 7 of Set 6 | port keats
# Processing Record 8 of Set 6 | marawi
# Processing Record 9 of Set 6 | bosaso
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | khatanga
# Processing Record 12 of Set 6 | florianopolis
# Processing Record 13 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 6 | tuatapere
# Processing Record 15 of Set 6 | alice springs
# Processing Record 16 of Set 6 | ust-tsilma
# Processing Record 17 of Set 6 | san quintin
# Processing Record 18 of Set 6 | grand forks
# Processing Record 19 of Set 6 | nuuk
# Processing Record 20 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 6 | aykhal
# Processing Record 22 of Set 6 | high level
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | mazagao
# Processing Record 25 of Set 6 | norman wells
# Processing Record 26 of Set 6 | valley
# Processing Record 27 of Set 6 | brae
# Processing Record 28 of Set 6 | east london
# Processing Record 29 of Set 6 | sellye
# Processing Record 30 of Set 6 | yamada
# Processing Record 31 of Set 6 | te anau
# Processing Record 32 of Set 6 | kansanshi
# Processing Record 33 of Set 6 | hunchun
# Processing Record 34 of Set 6 | kapit
# Processing Record 35 of Set 6 | finnsnes
# Processing Record 36 of Set 6 | liberal
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | linxia
# Processing Record 39 of Set 6 | arraial do cabo
# Processing Record 40 of Set 6 | eureka
# Processing Record 41 of Set 6 | darnah
# Processing Record 42 of Set 6 | burica
# City not found. Skipping...
# Processing Record 43 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 44 of Set 6 | muzhi
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | maragogi
# Processing Record 47 of Set 6 | domoni
# Processing Record 48 of Set 6 | kaeo
# Processing Record 49 of Set 6 | port hardy
# Processing Record 50 of Set 6 | college
# Processing Record 1 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 7 | isoka
# Processing Record 4 of Set 7 | paragominas
# Processing Record 5 of Set 7 | chimbote
# Processing Record 6 of Set 7 | maturin
# Processing Record 7 of Set 7 | morehead
# Processing Record 8 of Set 7 | mitsamiouli
# Processing Record 9 of Set 7 | gat
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | hualmay
# Processing Record 12 of Set 7 | carnarvon
# Processing Record 13 of Set 7 | luderitz
# Processing Record 14 of Set 7 | ukiah
# Processing Record 15 of Set 7 | des plaines
# Processing Record 16 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 7 | alofi
# Processing Record 18 of Set 7 | baependi
# Processing Record 19 of Set 7 | tungor
# Processing Record 20 of Set 7 | sao joao da barra
# Processing Record 21 of Set 7 | rona de jos
# Processing Record 22 of Set 7 | buala
# Processing Record 23 of Set 7 | mwene-ditu
# Processing Record 24 of Set 7 | gizo
# Processing Record 25 of Set 7 | russkiy
# Processing Record 26 of Set 7 | rasskazovo
# Processing Record 27 of Set 7 | nassau
# Processing Record 28 of Set 7 | saint-philippe
# Processing Record 29 of Set 7 | orotukan
# Processing Record 30 of Set 7 | grindavik
# Processing Record 31 of Set 7 | ulfborg
# Processing Record 32 of Set 7 | balkhash
# Processing Record 33 of Set 7 | yuanping
# Processing Record 34 of Set 7 | provideniya
# Processing Record 35 of Set 7 | san angelo
# Processing Record 36 of Set 7 | kudchi
# City not found. Skipping...
# Processing Record 37 of Set 7 | bucerias
# Processing Record 38 of Set 7 | coquimbo
# Processing Record 39 of Set 7 | kozhva
# Processing Record 40 of Set 7 | muana
# Processing Record 41 of Set 7 | russell
# Processing Record 42 of Set 7 | sao filipe
# Processing Record 43 of Set 7 | karaton
# Processing Record 44 of Set 7 | chifeng
# Processing Record 45 of Set 7 | hambantota
# Processing Record 46 of Set 7 | homer
# Processing Record 47 of Set 7 | anito
# Processing Record 48 of Set 7 | tezu
# Processing Record 49 of Set 7 | port-cartier
# Processing Record 50 of Set 7 | hammerfest
# Processing Record 1 of Set 8 | ayan
# Processing Record 2 of Set 8 | aksarka
# Processing Record 3 of Set 8 | kolimvari
# City not found. Skipping...
# Processing Record 4 of Set 8 | kaitangata
# Processing Record 5 of Set 8 | komsomolskiy
# Processing Record 6 of Set 8 | riyadh
# Processing Record 7 of Set 8 | koumac
# Processing Record 8 of Set 8 | shingu
# Processing Record 9 of Set 8 | bakel
# Processing Record 10 of Set 8 | sechura
# Processing Record 11 of Set 8 | pevek
# Processing Record 12 of Set 8 | long xuyen
# Processing Record 13 of Set 8 | port lincoln
# Processing Record 14 of Set 8 | coronado
# Processing Record 15 of Set 8 | redlands
# Processing Record 16 of Set 8 | tiarei
# Processing Record 17 of Set 8 | aragarcas
# Processing Record 18 of Set 8 | powell river
# Processing Record 19 of Set 8 | baker city
# Processing Record 20 of Set 8 | raudeberg
# Processing Record 21 of Set 8 | bambanglipuro
# Processing Record 22 of Set 8 | fairbanks
# Processing Record 23 of Set 8 | northam
# Processing Record 24 of Set 8 | grande-riviere
# City not found. Skipping...
# Processing Record 25 of Set 8 | ust-maya
# Processing Record 26 of Set 8 | at-bashi
# Processing Record 27 of Set 8 | port augusta
# Processing Record 28 of Set 8 | goya
# Processing Record 29 of Set 8 | kijang
# Processing Record 30 of Set 8 | bonavista
# Processing Record 31 of Set 8 | sao jose da coroa grande
# Processing Record 32 of Set 8 | dikson
# Processing Record 33 of Set 8 | vardo
# Processing Record 34 of Set 8 | greenville
# Processing Record 35 of Set 8 | okato
# Processing Record 36 of Set 8 | araria
# Processing Record 37 of Set 8 | sayat
# Processing Record 38 of Set 8 | muisne
# Processing Record 39 of Set 8 | guerrero negro
# Processing Record 40 of Set 8 | ixtapa
# Processing Record 41 of Set 8 | banikoara
# Processing Record 42 of Set 8 | mecca
# Processing Record 43 of Set 8 | cherskiy
# Processing Record 44 of Set 8 | richards bay
# Processing Record 45 of Set 8 | corowa
# Processing Record 46 of Set 8 | rovaniemi
# Processing Record 47 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 8 | bereda
# Processing Record 49 of Set 8 | iqaluit
# Processing Record 50 of Set 8 | pemba
# Processing Record 1 of Set 9 | lohardaga
# Processing Record 2 of Set 9 | marzuq
# Processing Record 3 of Set 9 | griffith
# Processing Record 4 of Set 9 | ivanivka
# Processing Record 5 of Set 9 | hovd
# Processing Record 6 of Set 9 | togur
# Processing Record 7 of Set 9 | nara
# Processing Record 8 of Set 9 | khash
# Processing Record 9 of Set 9 | geraldton
# Processing Record 10 of Set 9 | grenada
# Processing Record 11 of Set 9 | kautokeino
# Processing Record 12 of Set 9 | ust-nera
# Processing Record 13 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 14 of Set 9 | ust-kuyga
# Processing Record 15 of Set 9 | baloda bazar
# Processing Record 16 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 9 | takoradi
# Processing Record 18 of Set 9 | sioux lookout
# Processing Record 19 of Set 9 | ancud
# Processing Record 20 of Set 9 | katsuura
# Processing Record 21 of Set 9 | codrington
# Processing Record 22 of Set 9 | lao cai
# Processing Record 23 of Set 9 | verkhoyansk
# Processing Record 24 of Set 9 | urusha
# Processing Record 25 of Set 9 | santa cruz
# Processing Record 26 of Set 9 | saint-joseph
# Processing Record 27 of Set 9 | puerto colombia
# Processing Record 28 of Set 9 | karwar
# Processing Record 29 of Set 9 | santa quiteria
# Processing Record 30 of Set 9 | mao
# Processing Record 31 of Set 9 | huarmey
# Processing Record 32 of Set 9 | semnan
# Processing Record 33 of Set 9 | zavodouspenskoye
# Processing Record 34 of Set 9 | tautira
# Processing Record 35 of Set 9 | auki
# Processing Record 36 of Set 9 | villa union
# Processing Record 37 of Set 9 | ankang
# Processing Record 38 of Set 9 | urengoy
# Processing Record 39 of Set 9 | socorro
# Processing Record 40 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 9 | maningrida
# Processing Record 42 of Set 9 | gniezno
# Processing Record 43 of Set 9 | campoverde
# Processing Record 44 of Set 9 | bobonong
# City not found. Skipping...
# Processing Record 45 of Set 9 | bridgton
# Processing Record 46 of Set 9 | pangnirtung
# Processing Record 47 of Set 9 | kavieng
# Processing Record 48 of Set 9 | channelview
# Processing Record 49 of Set 9 | maumere
# Processing Record 50 of Set 9 | talnakh
# Processing Record 1 of Set 10 | husavik
# Processing Record 2 of Set 10 | manalurpet
# City not found. Skipping...
# Processing Record 3 of Set 10 | quelimane
# Processing Record 4 of Set 10 | beringovskiy
# Processing Record 5 of Set 10 | chippewa falls
# Processing Record 6 of Set 10 | ponta do sol
# Processing Record 7 of Set 10 | laiyang
# Processing Record 8 of Set 10 | taylorville
# Processing Record 9 of Set 10 | parana
# Processing Record 10 of Set 10 | laguna
# Processing Record 11 of Set 10 | sladkovo
# Processing Record 12 of Set 10 | novikovo
# Processing Record 13 of Set 10 | petropavlovka
# Processing Record 14 of Set 10 | kloulklubed
# Processing Record 15 of Set 10 | khandyga
# Processing Record 16 of Set 10 | murdochville
# Processing Record 17 of Set 10 | milevsko
# Processing Record 18 of Set 10 | koungou
# Processing Record 19 of Set 10 | prescott
# Processing Record 20 of Set 10 | neepawa
# Processing Record 21 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 10 | sahuaripa
# Processing Record 23 of Set 10 | erzin
# Processing Record 24 of Set 10 | portland
# Processing Record 25 of Set 10 | amuntai
# Processing Record 26 of Set 10 | play cu
# City not found. Skipping...
# Processing Record 27 of Set 10 | khor
# Processing Record 28 of Set 10 | obidos
# Processing Record 29 of Set 10 | sampit
# Processing Record 30 of Set 10 | isangel
# Processing Record 31 of Set 10 | macau
# Processing Record 32 of Set 10 | xining
# Processing Record 33 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 10 | kambove
# Processing Record 35 of Set 10 | vila velha
# Processing Record 36 of Set 10 | caravelas
# Processing Record 37 of Set 10 | alihe
# Processing Record 38 of Set 10 | sembe
# Processing Record 39 of Set 10 | psebay
# Processing Record 40 of Set 10 | maloh
# Processing Record 41 of Set 10 | kholm
# Processing Record 42 of Set 10 | vengerovo
# Processing Record 43 of Set 10 | glowno
# Processing Record 44 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 10 | tallahassee
# Processing Record 46 of Set 10 | gazli
# Processing Record 47 of Set 10 | viedma
# Processing Record 48 of Set 10 | narasannapeta
# Processing Record 49 of Set 10 | bozoum
# Processing Record 50 of Set 10 | wernberg
# Processing Record 1 of Set 11 | kearns
# Processing Record 2 of Set 11 | moba
# Processing Record 3 of Set 11 | wanaka
# Processing Record 4 of Set 11 | sinnar
# Processing Record 5 of Set 11 | bichena
# Processing Record 6 of Set 11 | bardiyah
# Processing Record 7 of Set 11 | okhotsk
# Processing Record 8 of Set 11 | ambon
# Processing Record 9 of Set 11 | leshukonskoye
# Processing Record 10 of Set 11 | stavern
# Processing Record 11 of Set 11 | cascavel
# Processing Record 12 of Set 11 | gorom-gorom
# Processing Record 13 of Set 11 | male
# Processing Record 14 of Set 11 | barlinek
# Processing Record 15 of Set 11 | kudahuvadhoo
# Processing Record 16 of Set 11 | flagstaff
# Processing Record 17 of Set 11 | svetlaya
# Processing Record 18 of Set 11 | providencia
# Processing Record 19 of Set 11 | srednekolymsk
# Processing Record 20 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 21 of Set 11 | liwale
# Processing Record 22 of Set 11 | upata
# Processing Record 23 of Set 11 | adre
# Processing Record 24 of Set 11 | jieshi
# Processing Record 25 of Set 11 | marsabit
# Processing Record 26 of Set 11 | jilin
# Processing Record 27 of Set 11 | chermoz
# Processing Record 28 of Set 11 | jalu
# Processing Record 29 of Set 11 | kandiari
# Processing Record 30 of Set 11 | makaryev
# Processing Record 31 of Set 11 | creston
# Processing Record 32 of Set 11 | galashki
# Processing Record 33 of Set 11 | taikang
# Processing Record 34 of Set 11 | gourcy
# Processing Record 35 of Set 11 | lata
# Processing Record 36 of Set 11 | honiara
# Processing Record 37 of Set 11 | port macquarie
# Processing Record 38 of Set 11 | burgersdorp
# Processing Record 39 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 11 | taywarah
# Processing Record 41 of Set 11 | panjakent
# Processing Record 42 of Set 11 | saryagash
# Processing Record 43 of Set 11 | presidente dutra
# Processing Record 44 of Set 11 | koroni
# Processing Record 45 of Set 11 | pudozh
# Processing Record 46 of Set 11 | cockburn town
# Processing Record 47 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 48 of Set 11 | chirongui
# Processing Record 49 of Set 11 | sept-iles
# Processing Record 50 of Set 11 | dhidhdhoo
# Processing Record 1 of Set 12 | esmeraldas
# Processing Record 2 of Set 12 | morant bay
# Processing Record 3 of Set 12 | jiuquan
# Processing Record 4 of Set 12 | paita
# Processing Record 5 of Set 12 | shiraoi
# Processing Record 6 of Set 12 | hohhot
# Processing Record 7 of Set 12 | manzanillo
# Processing Record 8 of Set 12 | severnyy
# Processing Record 9 of Set 12 | flinders
# Processing Record 10 of Set 12 | kudirkos naumiestis
# Processing Record 11 of Set 12 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 12 | agadez
# Processing Record 13 of Set 12 | leh
# Processing Record 14 of Set 12 | salalah
# Processing Record 15 of Set 12 | halifax
# Processing Record 16 of Set 12 | pacific grove
# Processing Record 17 of Set 12 | oranjemund
# Processing Record 18 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 12 | henties bay
# Processing Record 20 of Set 12 | bealanana
# Processing Record 21 of Set 12 | mogochin
# City not found. Skipping...
# Processing Record 22 of Set 12 | port hawkesbury
# Processing Record 23 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 12 | westport
# Processing Record 25 of Set 12 | pandan
# Processing Record 26 of Set 12 | camacha
# Processing Record 27 of Set 12 | masindi
# Processing Record 28 of Set 12 | panaba
# Processing Record 29 of Set 12 | nueva concepcion
# Processing Record 30 of Set 12 | jumla
# Processing Record 31 of Set 12 | monrovia
# Processing Record 32 of Set 12 | odienne
# Processing Record 33 of Set 12 | shubarshi
# Processing Record 34 of Set 12 | hay river
# Processing Record 35 of Set 12 | kuusamo
# Processing Record 36 of Set 12 | waipawa
# Processing Record 37 of Set 12 | kimbe
# Processing Record 38 of Set 12 | sur
# Processing Record 39 of Set 12 | joshimath
# Processing Record 40 of Set 12 | labuan
# Processing Record 41 of Set 12 | mogadouro
# Processing Record 42 of Set 12 | rio grande
# Processing Record 43 of Set 12 | miri
# Processing Record 44 of Set 12 | sungaipenuh
# Processing Record 45 of Set 12 | valleyview
# Processing Record 46 of Set 12 | tazovskiy
# Processing Record 47 of Set 12 | seymchan
# Processing Record 48 of Set 12 | bangassou
# Processing Record 49 of Set 12 | arman
# Processing Record 50 of Set 12 | limenaria
# Processing Record 1 of Set 13 | merauke
# Processing Record 2 of Set 13 | vangaindrano
# Processing Record 3 of Set 13 | yerbogachen
# Processing Record 4 of Set 13 | celestun
# Processing Record 5 of Set 13 | pasni
# Processing Record 6 of Set 13 | kasongo-lunda
# Processing Record 7 of Set 13 | fredonia
# Processing Record 8 of Set 13 | haifa
# Processing Record 9 of Set 13 | vanavara
# Processing Record 10 of Set 13 | zhanakorgan
# Processing Record 11 of Set 13 | gornyy
# Processing Record 12 of Set 13 | kropotkin
# Processing Record 13 of Set 13 | matagami
# Processing Record 14 of Set 13 | ibotirama
# Processing Record 15 of Set 13 | balkanabat
# Processing Record 16 of Set 13 | georgetown
# Processing Record 17 of Set 13 | fort frances
# Processing Record 18 of Set 13 | kishtwar
# Processing Record 19 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 13 | nang rong
# Processing Record 21 of Set 13 | tromso
# Processing Record 22 of Set 13 | dom pedrito
# Processing Record 23 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 24 of Set 13 | borgosesia
# Processing Record 25 of Set 13 | necochea
# Processing Record 26 of Set 13 | milkovo
# Processing Record 27 of Set 13 | ende
# Processing Record 28 of Set 13 | iquitos
# Processing Record 29 of Set 13 | addis zemen
# City not found. Skipping...
# Processing Record 30 of Set 13 | kuandian
# Processing Record 31 of Set 13 | jackson
# Processing Record 32 of Set 13 | saint-augustin
# Processing Record 33 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 13 | turukhansk
# Processing Record 35 of Set 13 | kontagora
# Processing Record 36 of Set 13 | nome
# Processing Record 37 of Set 13 | grand-lahou
# Processing Record 38 of Set 13 | velyka bahachka
# Processing Record 39 of Set 13 | howard springs
# Processing Record 40 of Set 13 | shelburne
# Processing Record 41 of Set 13 | banda aceh
# Processing Record 42 of Set 13 | moundou
# Processing Record 43 of Set 13 | traralgon
# Processing Record 44 of Set 13 | quesnel
# Processing Record 45 of Set 13 | raton
# Processing Record 46 of Set 13 | chengde
# Processing Record 47 of Set 13 | mormugao
# Processing Record 48 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 49 of Set 13 | marhaura
# Processing Record 50 of Set 13 | vetluzhskiy
# Processing Record 1 of Set 14 | tanete
# Processing Record 2 of Set 14 | ialibu
# Processing Record 3 of Set 14 | kutum
# Processing Record 4 of Set 14 | nata
# Processing Record 5 of Set 14 | yangjiang
# Processing Record 6 of Set 14 | anadyr
# Processing Record 7 of Set 14 | bayan
# Processing Record 8 of Set 14 | vostok
# Processing Record 9 of Set 14 | balassagyarmat
# Processing Record 10 of Set 14 | dunedin
# Processing Record 11 of Set 14 | manta
# Processing Record 12 of Set 14 | bogatyye saby
# Processing Record 13 of Set 14 | nemuro
# Processing Record 14 of Set 14 | san francisco
# Processing Record 15 of Set 14 | pontianak
# Processing Record 16 of Set 14 | matay
# Processing Record 17 of Set 14 | chupa
# Processing Record 18 of Set 14 | garden city
# Processing Record 19 of Set 14 | uniara
# Processing Record 20 of Set 14 | uruguaiana
# Processing Record 21 of Set 14 | vila franca do campo
# Processing Record 22 of Set 14 | kununurra
# Processing Record 23 of Set 14 | melton
# Processing Record 24 of Set 14 | shepsi
# Processing Record 25 of Set 14 | toktogul
# Processing Record 26 of Set 14 | sarangani
# Processing Record 27 of Set 14 | slave lake
# Processing Record 28 of Set 14 | cosala
# Processing Record 29 of Set 14 | lavrentiya
# Processing Record 30 of Set 14 | leon valley
# Processing Record 31 of Set 14 | palu
# Processing Record 32 of Set 14 | wuwei
# Processing Record 33 of Set 14 | athabasca
# Processing Record 34 of Set 14 | thunder bay
# Processing Record 35 of Set 14 | asosa
# Processing Record 36 of Set 14 | west melbourne
# Processing Record 37 of Set 14 | krasnovishersk
# Processing Record 38 of Set 14 | laela
# Processing Record 39 of Set 14 | misratah
# Processing Record 40 of Set 14 | shimoda
# Processing Record 41 of Set 14 | amapa
# Processing Record 42 of Set 14 | orcopampa
# Processing Record 43 of Set 14 | kiruna
# Processing Record 44 of Set 14 | atasu
# Processing Record 45 of Set 14 | santa isabel do rio negro
# Processing Record 46 of Set 14 | nelson bay
# Processing Record 47 of Set 14 | batticaloa
# Processing Record 48 of Set 14 | evensk
# Processing Record 49 of Set 14 | benghazi
# Processing Record 50 of Set 14 | sao luiz gonzaga
# Processing Record 1 of Set 15 | joppatowne
# Processing Record 2 of Set 15 | bac lieu
# Processing Record 3 of Set 15 | springbok
# Processing Record 4 of Set 15 | praia
# Processing Record 5 of Set 15 | corinto
# Processing Record 6 of Set 15 | waingapu
# Processing Record 7 of Set 15 | lovozero
# Processing Record 8 of Set 15 | kalianget
# Processing Record 9 of Set 15 | bonfim
# Processing Record 10 of Set 15 | talcahuano
# Processing Record 11 of Set 15 | comodoro rivadavia
# Processing Record 12 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 15 | tessalit
# Processing Record 14 of Set 15 | derzhavinsk
# Processing Record 15 of Set 15 | kindu
# Processing Record 16 of Set 15 | bud
# Processing Record 17 of Set 15 | clyde river
# Processing Record 18 of Set 15 | bridlington
# Processing Record 19 of Set 15 | ambulu
# Processing Record 20 of Set 15 | cabedelo
# Processing Record 21 of Set 15 | walla walla
# Processing Record 22 of Set 15 | acapulco
# Processing Record 23 of Set 15 | kandrian
# Processing Record 24 of Set 15 | arlit
# Processing Record 25 of Set 15 | tongling
# Processing Record 26 of Set 15 | goderich
# Processing Record 27 of Set 15 | walvis bay
# Processing Record 28 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 15 | maxixe
# Processing Record 30 of Set 15 | zyryanka
# Processing Record 31 of Set 15 | sinnamary
# Processing Record 32 of Set 15 | shenjiamen
# Processing Record 33 of Set 15 | charters towers
# Processing Record 34 of Set 15 | fort nelson
# Processing Record 35 of Set 15 | groningen
# Processing Record 36 of Set 15 | coihaique
# Processing Record 37 of Set 15 | brantford
# Processing Record 38 of Set 15 | yurimaguas
# Processing Record 39 of Set 15 | wattegama
# Processing Record 40 of Set 15 | sao francisco de assis
# Processing Record 41 of Set 15 | ures
# Processing Record 42 of Set 15 | abu samrah
# Processing Record 43 of Set 15 | mikhaylovka
# Processing Record 44 of Set 15 | serdobsk
# Processing Record 45 of Set 15 | vostochnyy
# Processing Record 46 of Set 15 | ban nahin
# Processing Record 47 of Set 15 | porto de moz
# Processing Record 48 of Set 15 | hobyo
# Processing Record 49 of Set 15 | green river
# Processing Record 50 of Set 15 | gladstone
# Processing Record 1 of Set 16 | umm kaddadah
# Processing Record 2 of Set 16 | anloga
# Processing Record 3 of Set 16 | loandjili
# Processing Record 4 of Set 16 | kimberley
# Processing Record 5 of Set 16 | rocha
# Processing Record 6 of Set 16 | gold coast
# Processing Record 7 of Set 16 | andenes
# Processing Record 8 of Set 16 | lincoln
# Processing Record 9 of Set 16 | taloqan
# Processing Record 10 of Set 16 | hornepayne
# Processing Record 11 of Set 16 | winnemucca
# Processing Record 12 of Set 16 | beloha
# Processing Record 13 of Set 16 | north branch
# Processing Record 14 of Set 16 | mantua
# Processing Record 15 of Set 16 | sesheke
# Processing Record 16 of Set 16 | aniva
# Processing Record 17 of Set 16 | paraiso
# Processing Record 18 of Set 16 | atyrau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Ugoofaaru   5.6667   73.0000     80.13        76          14        5.50
# 1   Ilulissat  69.2167  -51.1000     17.78        70         100        9.91
# 2  Butaritari   3.0707  172.7902     82.11        74          24       15.32
# 3    Hermanus -34.4187   19.2345     62.80        71          39        9.60
# 4      Torbay  47.6666  -52.7314     35.58        84         100       28.77
# 5      Kodiak  57.7900 -152.4072     40.51        93         100        8.05
# 6        Lasa  46.6166   10.7002     40.46        71          97        3.42
# 7       Vaini -21.2000 -175.2000     86.16        79          40        8.05
# 8     Autazes  -3.5797  -59.1306     74.95        98          97        1.59
# 9      Avarua -21.2078 -159.7750     84.25        74          40       18.41
#
#   Country                 Date       Description
# 0      MV  2022-02-03 22:54:25        few clouds
# 1      GL  2022-02-03 22:52:34   overcast clouds
# 2      KI  2022-02-03 22:50:30        light rain
# 3      ZA  2022-02-03 22:54:25  scattered clouds
# 4      CA  2022-02-03 22:50:29   overcast clouds
# 5      US  2022-02-03 22:49:30        light rain
# 6      IT  2022-02-03 22:54:26   overcast clouds
# 7      TO  2022-02-03 22:49:40  scattered clouds
# 8      BR  2022-02-03 22:54:27   overcast clouds
# 9      CK  2022-02-03 22:51:38  scattered clouds

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0   Ugoofaaru      MV  2022-02-03 22:54:25   5.6667   73.0000     80.13
# 1   Ilulissat      GL  2022-02-03 22:52:34  69.2167  -51.1000     17.78
# 2  Butaritari      KI  2022-02-03 22:50:30   3.0707  172.7902     82.11
# 3    Hermanus      ZA  2022-02-03 22:54:25 -34.4187   19.2345     62.80
# 4      Torbay      CA  2022-02-03 22:50:29  47.6666  -52.7314     35.58
# 5      Kodiak      US  2022-02-03 22:49:30  57.7900 -152.4072     40.51
# 6        Lasa      IT  2022-02-03 22:54:26  46.6166   10.7002     40.46
# 7       Vaini      TO  2022-02-03 22:49:40 -21.2000 -175.2000     86.16
# 8     Autazes      BR  2022-02-03 22:54:27  -3.5797  -59.1306     74.95
# 9      Avarua      CK  2022-02-03 22:51:38 -21.2078 -159.7750     84.25
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        76          14        5.50        few clouds
# 1        70         100        9.91   overcast clouds
# 2        74          24       15.32        light rain
# 3        71          39        9.60  scattered clouds
# 4        84         100       28.77   overcast clouds
# 5        93         100        8.05        light rain
# 6        71          97        3.42   overcast clouds
# 7        79          40        8.05  scattered clouds
# 8        98          97        1.59   overcast clouds
# 9        74          40       18.41  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
